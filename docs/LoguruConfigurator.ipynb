# %%
from loguru import logger
import sys
from rich import inspect

# %%
logger.debug("my first message")
logger.info("this is how it looks")
logger.error("wohoo")
logger.critical("ohhhhh")
# Out:
# 2024-04-12 17:26:31.884 | DEBUG    | __main__:<module>:1 - my first message
# 2024-04-12 17:26:31.886 | INFO     | __main__:<module>:2 - this is how it looks
# 2024-04-12 17:26:31.887 | ERROR    | __main__:<module>:3 - wohoo
# 2024-04-12 17:26:31.888 | CRITICAL | __main__:<module>:4 - ohhhhh

# %%
inspect(logger, methods=True)
# Out:
# ╭──────────────────────────────────────── <class 'loguru._logger.Logger'> ────────────────────────────────────────╮
# │ An object to dispatch logging messages to configured handlers.                                                  │
# │                                                                                                                 │
# │ ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮ │
# │ │ <loguru.logger handlers=[(id=0, level=10, sink=stderr), (id=1, level=10, sink=stdout), (id=2, level=10,     │ │
# │ │ sink=stdout), (id=3, level=10, sink=stdout), (id=7, level=10, sink=stdout)]>                                │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                                 │
# │           add = def add(sink, *, level='DEBUG', format='<green>{time:YYYY-MM-DD HH:mm:ss.SSS}</green> |         │
# │                 <level>{level: <8}</level> | <cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan> -  │
# │                 <level>{message}</level>', filter=None, colorize=None, serialize=False, backtrace=True,         │
# │                 diagnose=True, enqueue=False, context=None, catch=True, **kwargs): Add a handler sending log    │
# │                 messages to a sink adequately configured.                                                       │
# │          bind = def bind(**kwargs): Bind attributes to the ``extra`` dict of each logged message record.        │
# │         catch = def catch(exception=<class 'Exception'>, *, level='ERROR', reraise=False, onerror=None,         │
# │                 exclude=None, default=None, message="An error has been caught in function '{record[function]}', │
# │                 process '{record[process].name}' ({record[process].id}), thread '{record[thread].name}'         │
# │                 ({record[thread].id}):"): Return a decorator to automatically log possibly caught error in      │
# │                 wrapped function.                                                                               │
# │      complete = def complete(): Wait for the end of enqueued messages and asynchronous tasks scheduled by       │
# │                 handlers.                                                                                       │
# │     configure = def configure(*, handlers=None, levels=None, extra=None, patcher=None, activation=None):        │
# │                 Configure the core logger.                                                                      │
# │ contextualize = def contextualize(**kwargs): Bind attributes to the context-local ``extra`` dict while inside   │
# │                 the ``with`` block.                                                                             │
# │      critical = def critical(_Logger__message, *args, **kwargs): Log ``message.format(*args, **kwargs)`` with   │
# │                 severity ``'CRITICAL'``.                                                                        │
# │         debug = def debug(_Logger__message, *args, **kwargs): Log ``message.format(*args, **kwargs)`` with      │
# │                 severity ``'DEBUG'``.                                                                           │
# │       disable = def disable(name): Disable logging of messages coming from ``name`` module and its children.    │
# │        enable = def enable(name): Enable logging of messages coming from ``name`` module and its children.      │
# │         error = def error(_Logger__message, *args, **kwargs): Log ``message.format(*args, **kwargs)`` with      │
# │                 severity ``'ERROR'``.                                                                           │
# │     exception = def exception(_Logger__message, *args, **kwargs): Convenience method for logging an ``'ERROR'`` │
# │                 with exception information.                                                                     │
# │          info = def info(_Logger__message, *args, **kwargs): Log ``message.format(*args, **kwargs)`` with       │
# │                 severity ``'INFO'``.                                                                            │
# │         level = def level(name, no=None, color=None, icon=None): Add, update or retrieve a logging level.       │
# │           log = def log(_Logger__level, _Logger__message, *args, **kwargs): Log ``message.format(*args,         │
# │                 **kwargs)`` with severity ``level``.                                                            │
# │           opt = def opt(*, exception=None, record=False, lazy=False, colors=False, raw=False, capture=True,     │
# │                 depth=0, ansi=False): Parametrize a logging call to slightly change generated log message.      │
# │         parse = def parse(file, pattern, *, cast={}, chunk=65536): Parse raw logs and extract each entry as a   │
# │                 |dict|.                                                                                         │
# │         patch = def patch(patcher): Attach a function to modify the record dict created by each logging call.   │
# │        remove = def remove(handler_id=None): Remove a previously added handler and stop sending logs to its     │
# │                 sink.                                                                                           │
# │         start = def start(*args, **kwargs): Deprecated function to |add| a new handler.                         │
# │          stop = def stop(*args, **kwargs): Deprecated function to |remove| an existing handler.                 │
# │       success = def success(_Logger__message, *args, **kwargs): Log ``message.format(*args, **kwargs)`` with    │
# │                 severity ``'SUCCESS'``.                                                                         │
# │         trace = def trace(_Logger__message, *args, **kwargs): Log ``message.format(*args, **kwargs)`` with      │
# │                 severity ``'TRACE'``.                                                                           │
# │       warning = def warning(_Logger__message, *args, **kwargs): Log ``message.format(*args, **kwargs)`` with    │
# │                 severity ``'WARNING'``.                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
logger.remove()
my_format = "{time:YYYY-MM-DD HH:mm:ss.SSSS!UTC} <level>| {level} | {message} |</level> {extra} | {elapsed} - {module} - {name} - {function} - {line} - {process} - {thread} - {exception}"
logger_format =(
            "<green>{time:YYYY-MM-DD HH:mm:ss.SSSS!UTC}</green> | "
            "<level>{level: <8}</level> | "
            "<level>{message}</level> | "
            "<level>{extra}</level> | "
            "<cyan>M_{module}</cyan>:<cyan>N_{name}</cyan>:<cyan>f_{function}</cyan>:<cyan>line_{line}</cyan> | "
            "<m>t_{elapsed}</m>:<m>p_{process}</m>:<m>th_{thread}</m>:<m>ex_{exception}</m> | ")
id = logger.add(sys.stdout, colorize=True, format=logger_format)
logger.bind(id = str(id)).info(f"Now its that! {id}")
# Out:
# 2024-04-12 16:32:19.9766 | INFO     | Now its that! 7 | {'id': '7'} | M_3352173976:N___main__:f_<module>:line_11 | t_1:05:48.388686:p_10640:th_19980:ex_ |

# %%
logger.debug("my first message")
logger.info("this is how it looks")
logger.error("wohoo")
logger.critical("ohhhhh")
# Out:
# 2024-04-12 16:32:23.0138 | DEBUG    | my first message | {} | M_107586197:N___main__:f_<module>:line_1 | t_1:05:51.425917:p_10640:th_19980:ex_ |
# 2024-04-12 16:32:23.0158 | INFO     | this is how it looks | {} | M_107586197:N___main__:f_<module>:line_2 | t_1:05:51.427920:p_10640:th_19980:ex_ |
# 2024-04-12 16:32:23.0158 | ERROR    | wohoo | {} | M_107586197:N___main__:f_<module>:line_3 | t_1:05:51.427920:p_10640:th_19980:ex_ |
# 2024-04-12 16:32:23.0170 | CRITICAL | ohhhhh | {} | M_107586197:N___main__:f_<module>:line_4 | t_1:05:51.429110:p_10640:th_19980:ex_ |

# %%
logger.add(sys.stdout, format="json ouput", serialize=True)
logger.info("all in there!")
# Out:
# 2024-04-12 16:34:11.5795 | INFO     | all in there! | {} | M_1186843873:N___main__:f_<module>:line_2 | t_1:07:39.991613:p_10640:th_19980:ex_ |
# {"text": "json ouput\n", "record": {"elapsed": {"repr": "1:07:39.991613", "seconds": 4059.991613}, "exception": null, "extra": {}, "file": {"name": "1186843873.py", "path": "C:\\Users\\Lukas\\AppData\\Local\\Temp\\ipykernel_10640\\1186843873.py"}, "function": "<module>", "level": {"icon": "ℹ️", "name": "INFO", "no": 20}, "line": 2, "message": "all in there!", "module": "1186843873", "name": "__main__", "process": {"id": 10640, "name": "MainProcess"}, "thread": {"id": 19980, "name": "MainThread"}, "time": {"repr": "2024-04-12 18:34:11.579588+02:00", "timestamp": 1712939651.579588}}}

# %%
# for multiprocessing the logger has to be passed and the sink should have the enqueue=True option
logger.remove()
logger_format =(
            "<green>{time:YYYY-MM-DD HH:mm:ss.SSSS!UTC}</green> | "
            "<level>{level: <8}</level> | "
            "<level>{message}</level> | "
            "<level>{extra}</level> | "
            "<cyan>M_{module}</cyan>:<cyan>N_{name}</cyan>:<cyan>f_{function}</cyan>:<cyan>line_{line}</cyan> | "
            "<m>t_{elapsed}</m>:<m>p_{process}</m>:<m>th_{thread}</m>:<m>ex_{exception}</m> | ")
id = logger.add(sys.stdout, colorize=True, format=logger_format, enqueue=True)
logger.bind(id = str(id)).info(f"Now its that! {id}")
# Out:
# 2024-04-12 16:36:04.4360 | INFO     | Now its that! 9 | {'id': '9'} | M_4064308663:N___main__:f_<module>:line_11 | t_1:09:32.848122:p_10640:th_19980:ex_ |

# %%
import multiprocessing
import time
import random

def my_process(my_logger):
    for i in range(10):
        my_time = random.randint(1, 10)
        time.sleep(my_time/10)
        my_logger.info(f"Executing function in child process, waited for {my_time/10}s")
    my_logger.complete() # this makes sure that the process can end without interfering with the logger queue see: https://github.com/Delgan/loguru/issues/231

# %%
my_process(logger)
# Out:
# 2024-04-12 17:10:04.5297 | INFO     | Executing function in child process, waited for 0.1s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:32.941727:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:05.5392 | INFO     | Executing function in child process, waited for 1.0s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:33.951261:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:06.5512 | INFO     | Executing function in child process, waited for 1.0s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:34.963286:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:07.0643 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:35.476374:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:07.2659 | INFO     | Executing function in child process, waited for 0.2s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:35.677937:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:07.7662 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:36.178314:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:08.6780 | INFO     | Executing function in child process, waited for 0.9s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:37.090118:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:09.5903 | INFO     | Executing function in child process, waited for 0.9s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:38.002411:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:09.7934 | INFO     | Executing function in child process, waited for 0.2s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:38.205455:p_10640:th_19980:ex_ |
# 2024-04-12 17:10:10.3992 | INFO     | Executing function in child process, waited for 0.6s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:43:38.811301:p_10640:th_19980:ex_ |

# %%
# This doesen't work in a jupyter notebook!
process1 = multiprocessing.Process(target=my_process, args=())
process2 = multiprocessing.Process(target=my_process, args=())
process3 = multiprocessing.Process(target=my_process, args=())
process1.start()
process2.start()
process3.start()
process1.join()
process2.join()
process3.join()
logger.info("Done")
# Out:
# 2024-04-12 17:07:37.9430 | INFO     | Done | {} | M_543154228:N___main__:f_<module>:line_10 | t_1:41:06.355044:p_10640:th_19980:ex_ |

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
with ThreadPoolExecutor() as executor:
    futures = []
    for x in range(3):
        futures.append(executor.submit(my_process, logger))

result = [] # To store the processed images
for future in futures:
    result.append(future.result())
logger.info(f"len result: {len(result)}")
logger.info("Done!")
# Out:
# 2024-04-12 17:13:29.5823 | INFO     | Executing function in child process, waited for 0.1s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:57.994346:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:29.6759 | INFO     | Executing function in child process, waited for 0.2s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:58.087947:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:30.1864 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:58.598489:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:30.1864 | INFO     | Executing function in child process, waited for 0.6s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:58.598489:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:30.2805 | INFO     | Executing function in child process, waited for 0.8s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:58.692548:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:30.5905 | INFO     | Executing function in child process, waited for 0.4s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:59.002543:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:30.6987 | INFO     | Executing function in child process, waited for 0.1s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:59.110777:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:30.9927 | INFO     | Executing function in child process, waited for 0.8s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:59.404738:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:31.0872 | INFO     | Executing function in child process, waited for 0.8s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:59.499262:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:31.2125 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:46:59.624621:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:31.7285 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:00.140566:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:31.7904 | INFO     | Executing function in child process, waited for 0.7s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:00.202495:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:31.8056 | INFO     | Executing function in child process, waited for 0.8s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:00.217669:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:32.1181 | INFO     | Executing function in child process, waited for 0.3s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:00.530180:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:32.2413 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:00.653351:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:32.3188 | INFO     | Executing function in child process, waited for 0.2s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:00.730923:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:32.5977 | INFO     | Executing function in child process, waited for 0.8s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:01.009823:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:32.8317 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:01.243792:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:32.9404 | INFO     | Executing function in child process, waited for 0.1s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:01.352471:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:33.1427 | INFO     | Executing function in child process, waited for 0.9s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:01.554772:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:33.2043 | INFO     | Executing function in child process, waited for 0.6s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:01.616361:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:33.2502 | INFO     | Executing function in child process, waited for 0.1s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:01.662246:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:33.4554 | INFO     | Executing function in child process, waited for 0.5s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:01.867446:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:33.8637 | INFO     | Executing function in child process, waited for 0.4s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:02.275739:p_10640:th_31312:ex_ |
# 2024-04-12 17:13:34.1602 | INFO     | Executing function in child process, waited for 0.9s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:02.572270:p_10640:th_3744:ex_ |
# 2024-04-12 17:13:34.2063 | INFO     | Executing function in child process, waited for 1.0s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:02.618389:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:34.6128 | INFO     | Executing function in child process, waited for 0.4s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:03.024887:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:35.6212 | INFO     | Executing function in child process, waited for 1.0s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:04.033311:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:36.5258 | INFO     | Executing function in child process, waited for 0.9s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:04.937913:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:36.9305 | INFO     | Executing function in child process, waited for 0.4s | {} | M_445948885:N___main__:f_my_process:line_9 | t_1:47:05.342537:p_10640:th_21480:ex_ |
# 2024-04-12 17:13:36.9325 | INFO     | len result: 3 | {} | M_284222268:N___main__:f_<module>:line_9 | t_1:47:05.344540:p_10640:th_19980:ex_ |
# 2024-04-12 17:13:36.9325 | INFO     | Done! | {} | M_284222268:N___main__:f_<module>:line_10 | t_1:47:05.344540:p_10640:th_19980:ex_ |
